# %%
import pandas as pd 
import numpy as np
import plotly.express as px

# %%
df1 = pd.read_csv("diversity_school.csv")
df2 = pd.read_csv("tuition_cost.csv")

# %%
df = df1.merge(df2, left_on = ["name", "state"], right_on = ["name", "state"])

# %%
df.head()
# Out:
#                  name  total_enrollment     state  \
# 0  Liberty University             81459  Virginia
# 1  Liberty University             81459  Virginia
# 2  Liberty University             81459  Virginia
# 3  Liberty University             81459  Virginia
# 4  Liberty University             81459  Virginia
#
#                           category  enrollment state_code     type  \
# 0                            Women       48329         VA  Private
# 1  American Indian / Alaska Native         447         VA  Private
# 2                            Asian         856         VA  Private
# 3                            Black       14751         VA  Private
# 4                         Hispanic        1186         VA  Private
#
#   degree_length  room_and_board  in_state_tuition  in_state_total  \
# 0        4 Year         10478.0             25276           35754
# 1        4 Year         10478.0             25276           35754
# 2        4 Year         10478.0             25276           35754
# 3        4 Year         10478.0             25276           35754
# 4        4 Year         10478.0             25276           35754
#
#    out_of_state_tuition  out_of_state_total
# 0                 25276               35754
# 1                 25276               35754
# 2                 25276               35754
# 3                 25276               35754
# 4                 25276               35754

# %%
column_names = df.columns.tolist()
column_names
# Out:
# ['name',
#  'total_enrollment',
#  'state',
#  'category',
#  'enrollment',
#  'state_code',
#  'type',
#  'degree_length',
#  'room_and_board',
#  'in_state_tuition',
#  'in_state_total',
#  'out_of_state_tuition',
#  'out_of_state_total']

# %%
[df[i].unique() for i in column_names]
# Out:
# [array(['Liberty University', 'Miami Dade College',
#         'Grand Canyon University', ..., 'Family of Faith College',
#         'California Christian College', 'Myotherapy Institute'],
#        dtype=object),
#  array([81459, 66046, 62304, ...,    24,    20,    15], dtype=int64),
#  array(['Virginia', 'Florida', 'Arizona', 'Utah', 'Minnesota', 'Texas',
#         'California', 'Michigan', 'New York', 'Illinois', 'Washington',
#         'New Hampshire', 'Pennsylvania', 'Nevada', 'Ohio', 'Georgia',
#         'Iowa', 'North Carolina', 'Massachusetts', 'Oregon', 'Kentucky',
#         'West Virginia', 'New Mexico', 'Kansas', 'Connecticut', 'Alabama',
#         'Maryland', 'Tennessee', 'Delaware', 'Mississippi', 'Idaho',
#         'South Carolina', 'Missouri', 'New Jersey', 'Indiana', 'Colorado',
#         'Oklahoma', 'Rhode Island', 'Louisiana', 'Wisconsin',
#         'North Dakota', 'Vermont', 'Wyoming', 'South Dakota', 'Arkansas',
#         'Maine', 'Nebraska', 'Hawaii', 'Montana', 'Alaska'], dtype=object),
#  array(['Women', 'American Indian / Alaska Native', 'Asian', 'Black',
#         'Hispanic', 'Native Hawaiian / Pacific Islander', 'White',
#         'Two Or More Races', 'Unknown', 'Non-Resident Foreign',
#         'Total Minority'], dtype=object),
#  array([48329,   447,   856, ...,   942,   763,   445], dtype=int64),
#  array(['VA', 'FL', 'AZ', 'UT', 'MN', 'TX', 'CA', 'MI', 'NY', 'IL', 'WA',
#         'NH', 'PA', 'NV', 'OH', 'GA', 'IA', 'NC', 'MA', 'OR', 'KY', 'WV',
#         'NM', 'KS', 'CT', 'AL', 'MD', 'TN', 'DE', 'MS', 'ID', 'SC', 'MO',
#         'NJ', 'IN', 'CO', 'OK', 'RI', 'LA', 'WI', 'ND', 'VT', 'WY', 'SD',
#         'AR', 'ME', 'NE', 'HI', 'MT', 'AK'], dtype=object),
#  array(['Private', 'Public', 'For Profit'], dtype=object),
#  array(['4 Year', '2 Year'], dtype=object),
#  array([10478.,    nan, 10100., ...,  3400.,  1700.,  2400.]),
#  array([25276,  3547, 27090, ...,  7700,  9570, 11225], dtype=int64),
#  array([35754,  3547, 37190, ...,  7700,  8800, 11225], dtype=int64),
#  array([25276, 12075, 27090, ..., 11900,  9570, 11225], dtype=int64),
#  array([35754, 12075, 37190, ...,  7050, 14520, 11225], dtype=int64)]

# %%
[df[i].value_counts() for i in column_names]
# Out:
# [Liberty University                         11
#  Quinebaug Valley Community College         11
#  Ranken Technical College                   11
#  New Mexico State University at Carlsbad    11
#  Marymount Manhattan College                11
#                                             ..
#  Missouri Southern State University         11
#  Weatherford College                        11
#  Pennsylvania College of Technology         11
#  Westmoreland County Community College      11
#  Myotherapy Institute                       11
#  Name: name, Length: 2154, dtype: int64,
#  93      44
#  705     44
#  424     33
#  1867    33
#  1300    33
#          ..
#  6198    11
#  6203    11
#  6215    11
#  6242    11
#  15      11
#  Name: total_enrollment, Length: 1937, dtype: int64,
#  California        2134
#  Texas             1364
#  New York          1331
#  Pennsylvania      1199
#  North Carolina    1166
#  Illinois          1045
#  Ohio               946
#  Massachusetts      847
#  Georgia            748
#  Michigan           726
#  Florida            704
#  Virginia           638
#  Tennessee          550
#  Missouri           528
#  Minnesota          495
#  South Carolina     495
#  Washington         484
#  Alabama            473
#  Kansas             451
#  Iowa               440
#  Kentucky           440
#  New Jersey         440
#  Wisconsin          429
#  Oregon             374
#  Oklahoma           352
#  Maryland           352
#  Arkansas           341
#  Connecticut        330
#  Mississippi        330
#  Arizona            319
#  Colorado           319
#  Indiana            297
#  Louisiana          275
#  Nebraska           253
#  West Virginia      242
#  Maine              242
#  New Mexico         209
#  New Hampshire      198
#  North Dakota       176
#  South Dakota       176
#  Vermont            165
#  Montana            154
#  Rhode Island       110
#  Idaho              110
#  Nevada              77
#  Wyoming             66
#  Utah                44
#  Delaware            44
#  Hawaii              33
#  Alaska              33
#  Name: state, dtype: int64,
#  Women                                 2154
#  American Indian / Alaska Native       2154
#  Asian                                 2154
#  Black                                 2154
#  Hispanic                              2154
#  Native Hawaiian / Pacific Islander    2154
#  White                                 2154
#  Two Or More Races                     2154
#  Unknown                               2154
#  Non-Resident Foreign                  2154
#  Total Minority                        2154
#  Name: category, dtype: int64,
#  0       1667
#  1        563
#  2        464
#  3        398
#  4        341
#          ...
#  3330       1
#  4556       1
#  7565       1
#  7013       1
#  445        1
#  Name: enrollment, Length: 4512, dtype: int64,
#  CA    2134
#  TX    1364
#  NY    1331
#  PA    1199
#  NC    1166
#  IL    1045
#  OH     946
#  MA     847
#  GA     748
#  MI     726
#  FL     704
#  VA     638
#  TN     550
#  MO     528
#  MN     495
#  SC     495
#  WA     484
#  AL     473
#  KS     451
#  IA     440
#  KY     440
#  NJ     440
#  WI     429
#  OR     374
#  OK     352
#  MD     352
#  AR     341
#  CT     330
#  MS     330
#  AZ     319
#  CO     319
#  IN     297
#  LA     275
#  NE     253
#  WV     242
#  ME     242
#  NM     209
#  NH     198
#  ND     176
#  SD     176
#  VT     165
#  MT     154
#  RI     110
#  ID     110
#  NV      77
#  WY      66
#  UT      44
#  DE      44
#  HI      33
#  AK      33
#  Name: state_code, dtype: int64,
#  Public        12562
#  Private       10494
#  For Profit      638
#  Name: type, dtype: int64,
#  4 Year    14234
#  2 Year     9460
#  Name: degree_length, dtype: int64,
#  10200.0    77
#  7700.0     77
#  7400.0     77
#  9600.0     66
#  6000.0     55
#             ..
#  6156.0     11
#  16230.0    11
#  8950.0     11
#  15200.0    11
#  2400.0     11
#  Name: room_and_board, Length: 1127, dtype: int64,
#  1418     220
#  5310     132
#  1416      99
#  1420      88
#  4404      88
#          ...
#  42750     11
#  45948     11
#  6794      11
#  4425      11
#  11225     11
#  Name: in_state_tuition, Length: 1800, dtype: int64,
#  1418     209
#  5310     132
#  1416      99
#  1770      77
#  1420      77
#          ...
#  9050      11
#  28326     11
#  17104     11
#  12865     11
#  11225     11
#  Name: in_state_total, Length: 1914, dtype: int64,
#  18000    143
#  5220      88
#  9810      66
#  9160      55
#  8934      55
#          ...
#  3440      11
#  41310     11
#  33760     11
#  11792     11
#  11225     11
#  Name: out_of_state_tuition, Length: 1899, dtype: int64,
#  18000    143
#  5220      77
#  9810      77
#  8934      55
#  13172     44
#          ...
#  11590     11
#  12540     11
#  31283     11
#  39976     11
#  11225     11
#  Name: out_of_state_total, Length: 1979, dtype: int64]

# %%
# Check to find the null values in the dataframe

# %%
df.isin(["NA"]).any()
# Out:
# name                    False
# total_enrollment        False
# state                   False
# category                False
# enrollment              False
# state_code              False
# type                    False
# degree_length           False
# room_and_board          False
# in_state_tuition        False
# in_state_total          False
# out_of_state_tuition    False
# out_of_state_total      False
# dtype: bool

# %%
df.isin(["NaN"]).any()
# Out:
# name                    False
# total_enrollment        False
# state                   False
# category                False
# enrollment              False
# state_code              False
# type                    False
# degree_length           False
# room_and_board          False
# in_state_tuition        False
# in_state_total          False
# out_of_state_tuition    False
# out_of_state_total      False
# dtype: bool

# %%
df.isin([np.nan]).any()
# Out:
# name                    False
# total_enrollment        False
# state                   False
# category                False
# enrollment              False
# state_code              False
# type                    False
# degree_length           False
# room_and_board           True
# in_state_tuition        False
# in_state_total          False
# out_of_state_tuition    False
# out_of_state_total      False
# dtype: bool

# %%
df.replace(to_replace = np.nan, value = pd.NA, inplace = True)

# %%
df.head()
# Out:
#                  name  total_enrollment     state  \
# 0  Liberty University             81459  Virginia
# 1  Liberty University             81459  Virginia
# 2  Liberty University             81459  Virginia
# 3  Liberty University             81459  Virginia
# 4  Liberty University             81459  Virginia
#
#                           category  enrollment state_code     type  \
# 0                            Women       48329         VA  Private
# 1  American Indian / Alaska Native         447         VA  Private
# 2                            Asian         856         VA  Private
# 3                            Black       14751         VA  Private
# 4                         Hispanic        1186         VA  Private
#
#   degree_length room_and_board  in_state_tuition  in_state_total  \
# 0        4 Year        10478.0             25276           35754
# 1        4 Year        10478.0             25276           35754
# 2        4 Year        10478.0             25276           35754
# 3        4 Year        10478.0             25276           35754
# 4        4 Year        10478.0             25276           35754
#
#    out_of_state_tuition  out_of_state_total
# 0                 25276               35754
# 1                 25276               35754
# 2                 25276               35754
# 3                 25276               35754
# 4                 25276               35754

# %%
df["degree_length"].str.split(" ")[23689][0]
# Out:
# '2'

# %%
degree_num = []

# %%
# Example of splitting data in order to get the integer without the unit.
df["degree_length"].str.split(" ")[0][0]
# Out:
# '4'

# %%
#[degree_num.append(df["degree_length"].str.split(" ")[i][0]) for i in df["degree_length"]]

# %%
# Appends the number from the years seperately.
for i in range(len(df)):
    #print(df["degree_length"].str.split(" ")[i][0])
    x = df["degree_length"][i].split(" ")[0]
    x = int(x)
    degree_num.append(x)

# %%
df["degree_year_length"] = degree_num

# %%
df.head()
# Out:
#                  name  total_enrollment     state  \
# 0  Liberty University             81459  Virginia
# 1  Liberty University             81459  Virginia
# 2  Liberty University             81459  Virginia
# 3  Liberty University             81459  Virginia
# 4  Liberty University             81459  Virginia
#
#                           category  enrollment state_code     type  \
# 0                            Women       48329         VA  Private
# 1  American Indian / Alaska Native         447         VA  Private
# 2                            Asian         856         VA  Private
# 3                            Black       14751         VA  Private
# 4                         Hispanic        1186         VA  Private
#
#   degree_length room_and_board  in_state_tuition  in_state_total  \
# 0        4 Year        10478.0             25276           35754
# 1        4 Year        10478.0             25276           35754
# 2        4 Year        10478.0             25276           35754
# 3        4 Year        10478.0             25276           35754
# 4        4 Year        10478.0             25276           35754
#
#    out_of_state_tuition  out_of_state_total  degree_year_length
# 0                 25276               35754                   4
# 1                 25276               35754                   4
# 2                 25276               35754                   4
# 3                 25276               35754                   4
# 4                 25276               35754                   4

# %%
# Verify that all of the units are indeed years, just like the degree_year_length supouses.
df["degree_length"].value_counts()
# Out:
# 4 Year    14234
# 2 Year     9460
# Name: degree_length, dtype: int64

# %%
df_name = df.groupby("name").min().reset_index()

# %%
df_name.head()
# Out:
#                                    name  total_enrollment       state  \
# 0                Aaniiih Nakoda College               291     Montana
# 1          Abilene Christian University              4427       Texas
# 2  Abraham Baldwin Agricultural College              3458     Georgia
# 3                       Academy College               127   Minnesota
# 4             Academy of Art University             15212  California
#
#                           category  enrollment state_code        type  \
# 0  American Indian / Alaska Native           0         MT      Public
# 1  American Indian / Alaska Native           0         TX     Private
# 2  American Indian / Alaska Native           1         GA      Public
# 3  American Indian / Alaska Native           0         MN  For Profit
# 4  American Indian / Alaska Native          70         CA  For Profit
#
#   degree_length  room_and_board  in_state_tuition  in_state_total  \
# 0        2 Year             NaN              2380            2380
# 1        4 Year         10350.0             34850           45200
# 2        2 Year          8474.0              4128           12602
# 3        2 Year             NaN             17661           17661
# 4        4 Year         16648.0             27810           44458
#
#    out_of_state_tuition  out_of_state_total  degree_year_length
# 0                  2380                2380                   2
# 1                 34850               45200                   4
# 2                 12550               21024                   2
# 3                 17661               17661                   2
# 4                 27810               44458                   4

# %%
px.bar(df_name, x = df_name.value_counts().index, y = df_name.value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [102], in <cell line: 1>()
# ----> 1 px.bar(df_name, x = df_name.value_counts().index, y = df_name.value_counts())
#
# File ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
#     327     x=None,
#    (...)
#     367     height=None,
#     368 ) -> go.Figure:
#     369     """
#     370     In a bar plot, each row of `data_frame` is represented as a rectangular
#     371     mark.
#     372     """
# --> 373     return make_figure(
#     374         args=locals(),
#     375         constructor=go.Bar,
#     376         trace_patch=dict(textposition="auto"),
#     377         layout_patch=dict(barmode=barmode),
#     378     )
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1148, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1146 # Case of multiindex
#    1147 if isinstance(argument, pd.MultiIndex):
# -> 1148     raise TypeError(
#    1149         "Argument '%s' is a pandas MultiIndex. "
#    1150         "pandas MultiIndex is not supported by plotly express "
#    1151         "at the moment." % field
#    1152     )
#    1153 # ----------------- argument is a special value ----------------------
#    1154 if isinstance(argument, Constant) or isinstance(argument, Range):
#
# TypeError: Argument 'x' is a pandas MultiIndex. pandas MultiIndex is not supported by plotly express at the moment.

# %%
room_board_null = pd.isnull(df["room_and_board"])

# %%
df.loc[room_board_null]["name"]
# Out:
# 11         Miami Dade College
# 12         Miami Dade College
# 13         Miami Dade College
# 14         Miami Dade College
# 15         Miami Dade College
#                  ...
# 23689    Myotherapy Institute
# 23690    Myotherapy Institute
# 23691    Myotherapy Institute
# 23692    Myotherapy Institute
# 23693    Myotherapy Institute
# Name: name, Length: 8349, dtype: object

# %%
list_of_nulls = df.loc[room_board_null]["name"].unique().tolist()

# %%
list_of_nulls.sort()

# %%
list_of_nulls
# Out:
# ['Aaniiih Nakoda College',
#  'Academy College',
#  'Advanced Technology Institute',
#  'Aiken Technical College',
#  'Aims Community College',
#  'Alabama Southern Community College',
#  'Alamance Community College',
#  'Albany Technical College',
#  'Alexandria Technical and Community College',
#  'Allan Hancock College',
#  'Allegany College of Maryland',
#  'Alpena Community College',
#  'Alvernia University',
#  'Alvin Community College',
#  'Amarillo College',
#  'American Academy McAllister Institute of Funeral Service',
#  'American Academy of Art',
#  'American River College',
#  'Amridge University',
#  'Anne Arundel Community College',
#  'Anoka Technical College',
#  'Anoka-Ramsey Community College',
#  'Antelope Valley College',
#  'Antioch University Midwest',
#  'Apex School of Theology',
#  'Arapahoe Community College',
#  'Arkansas Northeastern College',
#  'Art Center College of Design',
#  'Art Institute of Philadelphia',
#  'Asheville-Buncombe Technical Community College',
#  'Ashford University',
#  'Ashland Community and Technical College',
#  'Asnuntuck Community College',
#  'Athens State University',
#  'Athens Technical College',
#  'Atlanta Metropolitan State College',
#  'Atlanta Technical College',
#  'Atlantic Cape Community College',
#  'Augusta Technical College',
#  'Aultman College of Nursing and Health Sciences',
#  'Austin Community College',
#  'Austin Graduate School of Theology',
#  'Bakersfield College',
#  'Baltimore City Community College',
#  'Barstow Community College',
#  'Bates Technical College',
#  'Baton Rouge Community College',
#  'Bay Mills Community College',
#  'Beaufort County Community College',
#  'Bellevue College',
#  'Bellin College',
#  'Bellingham Technical College',
#  'Belmont College',
#  'Bergen Community College',
#  'Bergin University of Canine Studies',
#  'Berkeley City College',
#  'Berkshire Community College',
#  'Beth Hatalmud Rabbinical College',
#  'Bethesda University of California',
#  'Big Sandy Community and Technical College',
#  'Bishop State Community College',
#  'Black Hawk College',
#  'Black River Technical College',
#  'Blackhawk Technical College',
#  'Bladen Community College',
#  'Blue Mountain Community College',
#  'Blue Ridge Community and Technical College',
#  'Bluefield State College',
#  'Bluegrass Community and Technical College',
#  'Boricua College',
#  'Bossier Parish Community College',
#  'Brandman University',
#  'Brazosport College',
#  'Bristol Community College',
#  'Brookdale Community College',
#  'Brookhaven College',
#  'Broward College',
#  'Brunswick Community College',
#  'Bryan College of Health Sciences',
#  'Bunker Hill Community College',
#  'Butte College',
#  'Cabarrus College of Health Sciences',
#  'Cabrillo College',
#  'Caldwell Community College and Technical Institute',
#  'Calhoun Community College',
#  'California Institute of Integral Studies',
#  'California Miramar University',
#  'California University of Management and Sciences',
#  'Cambridge College',
#  'Camden County College',
#  'Canada College',
#  'Cankdeska Cikana Community College',
#  'Cape Cod Community College',
#  'Cape Fear Community College',
#  'Capella University',
#  'Capital Community College',
#  'Career College of Northern Nevada',
#  'Carl Sandburg College',
#  'Carolina Christian College',
#  'Carroll Community College',
#  'Carteret Community College',
#  'Catawba Valley Community College',
#  'Cayuga Community College',
#  'Cecil College',
#  'Cedar Valley College',
#  'Central Alabama Community College',
#  'Central Carolina Community College',
#  'Central Carolina Technical College',
#  'Central Georgia Technical College',
#  'Central New Mexico Community College',
#  'Central Ohio Technical College',
#  'Central Piedmont Community College',
#  'Central Virginia Community College',
#  'Centralia College',
#  'Century College',
#  'Cerritos College',
#  'Cerro Coso Community College',
#  'Chabot College',
#  'Chaffey College',
#  'Chandler-Gilbert Community College',
#  'Charter Oak State College',
#  'Chatfield College',
#  'Chattahoochee Technical College',
#  'Chattahoochee Valley Community College',
#  'Chattanooga State Community College',
#  'Chemeketa Community College',
#  'Chesapeake College',
#  'Chief Dull Knife College',
#  'Chipola College',
#  'Chippewa Valley Technical College',
#  'Cincinnati College of Mortuary Science',
#  'Cincinnati State Technical and Community College',
#  'Citrus College',
#  'City College of San Francisco',
#  'Clackamas Community College',
#  'Clark College',
#  'Clark State Community College',
#  'Clatsop Community College',
#  'Cleveland Community College',
#  'Cleveland State Community College',
#  'Clover Park Technical College',
#  'Clovis Community College',
#  'Coastal Carolina Community College',
#  'Coastal Pines Technical College',
#  'Coastline Community College',
#  'Cochran School of Nursing',
#  'Coleman University',
#  'College of Alameda',
#  'College of Central Florida',
#  'College of Court Reporting',
#  'College of DuPage',
#  'College of Lake County',
#  'College of Marin',
#  'College of Menominee Nation',
#  'College of San Mateo',
#  'College of Southern Maryland',
#  'College of Southern Nevada',
#  'College of Western Idaho',
#  'College of the Albemarle',
#  'College of the Canyons',
#  'College of the Desert',
#  'College of the Mainland',
#  'College of the Ouachitas',
#  'College of the Sequoias',
#  'Colorado School of Healing Arts',
#  'Colorado School of Trades',
#  'Columbia Basin College',
#  'Columbia College Hollywood',
#  'Columbia College of Nursing',
#  'Columbia Southern University',
#  'Columbia State Community College',
#  'Columbia-Greene Community College',
#  'Columbus State Community College',
#  'Columbus Technical College',
#  'Commonwealth Institute of Funeral Service',
#  'Community College of Allegheny County',
#  'Community College of Aurora',
#  'Community College of Baltimore County',
#  'Community College of Beaver County',
#  'Community College of Denver',
#  'Community College of Philadelphia',
#  'Community College of Rhode Island',
#  'Community College of Vermont',
#  'Contra Costa College',
#  'Copper Mountain College',
#  'Cossatot Community College of the University of Arkansas',
#  'Cosumnes River College',
#  'County College of Morris',
#  'Cox College',
#  'Crafton Hills College',
#  'Craven Community College',
#  'Creative Center',
#  'Criswell College',
#  'Crossroads Bible College',
#  'Cuesta College',
#  'Culinary Institute LeNotre',
#  'Cumberland County College',
#  'Cuyahoga Community College',
#  'Cuyamaca College',
#  'Cypress College',
#  'Dabney S. Lancaster Community College',
#  'Dakota County Technical College',
#  'Dallas Institute of Funeral Service',
#  'Danville Area Community College',
#  'Danville Community College',
#  'Davidson County Community College',
#  'Daytona State College',
#  'De Anza College',
#  'Del Mar College',
#  'Delgado Community College',
#  'Delta College',
#  'Design Institute of San Diego',
#  'Diablo Valley College',
#  'DigiPen Institute of Technology',
#  'Donnelly College',
#  'Durham Technical Community College',
#  'Dyersburg State Community College',
#  'ETI Technical College of Niles',
#  'East Arkansas Community College',
#  'East Central College',
#  'East Los Angeles College',
#  'East-West University',
#  'Eastern Gateway Community College',
#  'Eastern Shore Community College',
#  'Eastern West Virginia Community and Technical College',
#  'Eastfield College',
#  'Edgecombe Community College',
#  'Edison State Community College',
#  'El Camino College',
#  'El Centro College',
#  'El Paso Community College',
#  'Elgin Community College',
#  'Elizabethtown Community and Technical College',
#  'Elmira Business Institute',
#  'Enterprise State Community College',
#  'Essex County College',
#  'Estrella Mountain Community College',
#  'Evergreen Valley College',
#  'Fayetteville Technical Community College',
#  'Flathead Valley Community College',
#  'Florence-Darlington Technical College',
#  'Florida Gateway College',
#  'Florida State College at Jacksonville',
#  'Folsom Lake College',
#  'Foothill College',
#  'Forsyth Technical Community College',
#  'Fox Valley Technical College',
#  'Franklin University',
#  'Frederick Community College',
#  'Fremont College',
#  'Fresno City College',
#  'Front Range Community College',
#  'Fullerton College',
#  'Galveston College',
#  'Gaston College',
#  'Gateway Community and Technical College',
#  'Gateway Technical College',
#  'Gavilan College',
#  'Georgia Highlands College',
#  'Georgia Military College',
#  'Georgia Northwestern Technical College',
#  'Georgia Piedmont Technical College',
#  'Germanna Community College',
#  'Glen Oaks Community College',
#  'Glenville State College',
#  "God's Bible School and College",
#  'Golden Gate University',
#  'Golden West College',
#  'Goldfarb School of Nursing at Barnes-Jewish College',
#  'Good Samaritan College of Nursing and Health Science',
#  'Goodwin College',
#  'Grand Rapids Community College',
#  'Granite State College',
#  'Grantham University',
#  'Gratz College',
#  'Grays Harbor College',
#  'Great Bay Community College',
#  'Greenfield Community College',
#  'Greenville Technical College',
#  'Grossmont College',
#  'Guilford Technical Community College',
#  'Gulf Coast State College',
#  'Gupton Jones College of Funeral Service',
#  'Gwinnett College',
#  'Gwinnett Technical College',
#  'Hagerstown Community College',
#  'Halifax Community College',
#  'Harford Community College',
#  'Harper College',
#  'Harrisburg Area Community College',
#  'Hartnell College',
#  'Hawkeye Community College',
#  'Haywood Community College',
#  'Hazard Community and Technical College',
#  'Heartland Community College',
#  'Helene Fuld College of Nursing',
#  'Henderson Community College',
#  'Hennepin Technical College',
#  'Hillsborough Community College',
#  'Hodges University',
#  'Holy Apostles College and Seminary',
#  'Holyoke Community College',
#  'Hopkinsville Community College',
#  'Horizon University',
#  'Horry-Georgetown Technical College',
#  'Housatonic Community College',
#  'Howard Community College',
#  'Hudson County Community College',
#  'Hudson Valley Community College',
#  'Humphreys College',
#  'Huntsville Bible College',
#  'Illinois Central College',
#  'Illinois Valley Community College',
#  'Imperial Valley College',
#  'Indian River State College',
#  'Indiana University East',
#  'International College of Broadcasting',
#  'Inver Hills Community College',
#  'Irvine Valley College',
#  'Island Drafting and Technical Institute',
#  'Isothermal Community College',
#  'J. Sargeant Reynolds Community College',
#  'JNA Institute of Culinary Arts',
#  'Jackson State Community College',
#  'James A. Rhodes State College',
#  'James Sprunt Community College',
#  'Jamestown Business College',
#  'Jefferson Community and Technical College',
#  'Jefferson State Community College',
#  'John A. Gupton College',
#  'John A. Logan College',
#  'John F. Kennedy University',
#  'John Tyler Community College',
#  'John Wood Community College',
#  'Johnson County Community College',
#  'Johnston Community College',
#  'Joliet Junior College',
#  'Kalamazoo Valley Community College',
#  'Kankakee Community College',
#  'Kansas City Kansas Community College',
#  'Kaskaskia College',
#  'Kellogg Community College',
#  'Kennebec Valley Community College',
#  'Key College',
#  'Kirkwood Community College',
#  'Kirtland Community College',
#  'Kishwaukee College',
#  'Klamath Community College',
#  'Labette Community College',
#  'Laboure College',
#  'Lac Courte Oreilles Ojibwa Community College',
#  'Lake Area Technical Institute',
#  'Lake Land College',
#  'Lake Superior College',
#  'Lake Tahoe Community College',
#  'Lake Washington Institute of Technology',
#  'Lake-Sumter State College',
#  'Lakeland Community College',
#  'Lakes Region Community College',
#  'Lakeshore Technical College',
#  'Lakeview College of Nursing',
#  'Lamar Institute of Technology',
#  'Lane Community College',
#  'Laney College',
#  'Lansing Community College',
#  'Laredo Community College',
#  'Las Positas College',
#  'Lee College',
#  'Leech Lake Tribal College',
#  'Lehigh Carbon Community College',
#  'Lenoir Community College',
#  'Lewis and Clark Community College',
#  'Lincoln Land Community College',
#  'Linn-Benton Community College',
#  'Little Big Horn College',
#  'Logan University',
#  'Long Beach City College',
#  'Long Island Business Institute',
#  'Lorain County Community College',
#  'Lord Fairfax Community College',
#  'Los Angeles City College',
#  'Los Angeles County College of Nursing and Allied Health',
#  'Los Angeles Harbor College',
#  'Los Angeles Mission College',
#  'Los Angeles Pierce College',
#  'Los Angeles Southwest College',
#  'Los Angeles Valley College',
#  'Los Medanos College',
#  'Louisiana State University at Alexandria',
#  'Lower Columbia College',
#  'Luna Community College',
#  'Lurleen B. Wallace Community College',
#  'Luzerne County Community College',
#  'MacCormac College',
#  'Machzikei Hadath Rabbinical College',
#  'Macomb Community College',
#  'Madison Area Technical College',
#  'Madisonville Community College',
#  'Manhattan Area Technical College',
#  'Manthano Christian College',
#  'Marion Technical College',
#  'Marshalltown Community College',
#  'Martin Community College',
#  'Marylhurst University',
#  'Massachusetts Bay Community College',
#  'Massasoit Community College',
#  'Mayland Community College',
#  'Maysville Community and Technical College',
#  'McDowell Technical Community College',
#  'McHenry County College',
#  'McLennan Community College',
#  'Medical University of South Carolina',
#  'Mendocino College',
#  'Merced College',
#  'Mercer County Community College',
#  'Mercy College of Health Sciences',
#  'Meridian Community College',
#  'Merritt College',
#  'Mesa Community College',
#  'Metropolitan College of New York',
#  'Metropolitan State University',
#  'Miami Dade College',
#  'Michigan Jewish Institute',
#  'Mid Michigan Community College',
#  'Mid-America College of Funeral Service',
#  'Mid-State Technical College',
#  'Middlesex Community College',
#  'Middlesex County College',
#  'Midlands Technical College',
#  'Midstate College',
#  'Milwaukee Area Technical College',
#  'Minnesota West Community and Technical College',
#  'Mission College',
#  'Missouri Western State University',
#  'Mitchell Community College',
#  'Mitchell Technical Institute',
#  'Modesto Junior College',
#  'Mohave Community College',
#  'Monroe County Community College',
#  'Montcalm Community College',
#  'Monterey Peninsula College',
#  'Montgomery Community College',
#  'Montgomery County Community College',
#  'Moorpark College',
#  'Moraine Park Technical College',
#  'Moraine Valley Community College',
#  'Moreno Valley College',
#  'Morgan Community College',
#  'Morton College',
#  'Motlow State Community College',
#  'Mott Community College',
#  'Mount Wachusett Community College',
#  'Mountain Empire Community College',
#  'Mountain View College',
#  'Mt. Hood Community College',
#  'Mt. Sierra College',
#  'Muskegon Community College',
#  'Myotherapy Institute',
#  'Napa Valley College',
#  'Nash Community College',
#  'Nashua Community College',
#  'Nashville State Community College',
#  'Nassau Community College',
#  'National Paralegal College',
#  'National University',
#  'National University of Health Sciences',
#  'National-Louis University',
#  'Naugatuck Valley Community College',
#  'Nazarene Bible College',
#  'Nebraska Indian Community College',
#  'Nevada State College',
#  'New Mexico State University at Alamogordo',
#  'New Mexico State University at Carlsbad',
#  'New River Community College',
#  'New River Community and Technical College',
#  'Niagara County Community College',
#  'Nicolet Area Technical College',
#  'Norco College',
#  'Normandale Community College',
#  'North Arkansas College',
#  'North Central State College',
#  'North Florida Community College',
#  'North Hennepin Community College',
#  'North Lake College',
#  'North Shore Community College',
#  'Northcentral Technical College',
#  'Northeast Alabama Community College',
#  'Northeast Iowa Community College',
#  'Northeast State Community College',
#  'Northeast Wisconsin Technical College',
#  'Northeastern Technical College',
#  'Northern Essex Community College',
#  'Northern New Mexico College',
#  'Northern Virginia Community College',
#  'Northland Pioneer College',
#  'Northwest Florida State College',
#  'Northwest Iowa Community College',
#  'Northwest State Community College',
#  'Northwest Technical College',
#  'Northwest Vista College',
#  'Northwest-Shoals Community College',
#  'Northwestern Connecticut Community College',
#  'Northwestern Health Sciences University',
#  'Norwalk Community College',
#  'Nossi College of Art',
#  'Nunez Community College',
#  "O'More College of Design",
#  'Oakland Community College',
#  'Oakton Community College',
#  'Ocean County College',
#  'Oglala Lakota College',
#  'Ohio Technical College',
#  'Ohlone College',
#  'Oklahoma City Community College',
#  'Orange Coast College',
#  'Orange County Community College',
#  'Orangeburg-Calhoun Technical College',
#  'Oregon Health & Science University',
#  'Our Lady of the Lake College',
#  'Owens Community College',
#  'Owensboro Community and Technical College',
#  'Oxnard College',
#  'Ozarka College',
#  'Ozarks Technical Community College',
#  'Pacific Oaks College',
#  'Pacific States University',
#  'Paier College of Art',
#  'Palm Beach State College',
#  'Palo Alto College',
#  'Palo Verde College',
#  'Palomar College',
#  'Pamlico Community College',
#  'Paradise Valley Community College',
#  'Parkland College',
#  'Pasadena City College',
#  'Passaic County Community College',
#  'Patrick Henry Community College',
#  'Paul D. Camp Community College',
#  'Peirce College',
#  'Pellissippi State Community College',
#  'Peninsula College',
#  'Pennsylvania Academy of the Fine Arts',
#  'Pennsylvania College of Health Sciences',
#  'Pennsylvania Highlands Community College',
#  'Pensacola State College',
#  'Phillips Community College of the University of Arkansas',
#  'Phoenix College',
#  'Piedmont Community College',
#  'Piedmont Technical College',
#  'Piedmont Virginia Community College',
#  'Pikes Peak Community College',
#  'Pillar College',
#  'Pima Community College',
#  'Pitt Community College',
#  'Pittsburgh Institute of Aeronautics',
#  'Pittsburgh Institute of Mortuary Science',
#  'Polk State College',
#  'Porterville College',
#  'Portland Community College',
#  'Prairie State College',
#  "Prince George's Community College",
#  'Pueblo Community College',
#  'Quincy College',
#  'Quinebaug Valley Community College',
#  'Quinsigamond Community College',
#  'Randolph Community College',
#  'Ranken Technical College',
#  'Rappahannock Community College',
#  'Raritan Valley Community College',
#  'Reading Area Community College',
#  'Red Rocks Community College',
#  'Refrigeration School',
#  'Rend Lake College',
#  'Renton Technical College',
#  'Resurrection University',
#  'Richland College',
#  'Richland Community College',
#  'Richmond Community College',
#  'Ridgewater College',
#  'Rio Hondo College',
#  'River Parishes Community College',
#  'River Valley Community College',
#  'Riverland Community College',
#  'Roane State Community College',
#  'Roanoke-Chowan Community College',
#  'Robeson Community College',
#  'Rochester Community and Technical College',
#  'Rock Valley College',
#  'Rockingham Community College',
#  'Rockland Community College',
#  'Rogue Community College',
#  'Rowan-Cabarrus Community College',
#  'Roxbury Community College',
#  'Rush University',
#  'Sacramento City College',
#  'Saddleback College',
#  'Sage College',
#  'Saginaw Chippewa Tribal College',
#  'Saint Anthony College of Nursing',
#  "Saint Luke's College of Health Sciences",
#  'Salem Community College',
#  'Salish Kootenai College',
#  'Sampson Community College',
#  'San Antonio College',
#  'San Bernardino Valley College',
#  'San Diego City College',
#  'San Diego Mesa College',
#  'San Diego Miramar College',
#  'San Joaquin Delta College',
#  'San Jose City College',
#  'San Juan College',
#  'Sandhills Community College',
#  'Santa Ana College',
#  'Santa Barbara City College',
#  'Santa Fe College',
#  'Santa Monica College',
#  'Santa Rosa Junior College',
#  'Santiago Canyon College',
#  'Sauk Valley Community College',
#  'Savannah Technical College',
#  'Schenectady County Community College',
#  'Schiller International University',
#  'School of Advertising Art',
#  'Schoolcraft College',
#  'Scottsdale Community College',
#  'Seminole State College of Florida',
#  'Sessions College for Professional Design',
#  'Shasta College',
#  'Shawnee Community College',
#  'Shelton State Community College',
#  'Sinclair Community College',
#  'Sinte Gleska University',
#  'Sitting Bull College',
#  'Skagit Valley College',
#  'Skyline College',
#  'Solano Community College',
#  'Somerset Community College',
#  'South Arkansas Community College',
#  'South Central College',
#  'South Coast College',
#  'South Florida State College',
#  'South Louisiana Community College',
#  'South Mountain Community College',
#  'South Piedmont Community College',
#  'South Puget Sound Community College',
#  'South Suburban College of Cook County',
#  'South Texas College',
#  'Southeast Arkansas College',
#  'Southeast Kentucky Community and Technical College',
#  'Southeast Missouri Hospital College of Nursing and Health Sciences',
#  'Southeast Technical Institute',
#  'Southeastern Illinois College',
#  'Southeastern Technical College',
#  'Southern California Institute of Architecture',
#  'Southern California Institute of Technology',
#  'Southern Crescent Technical College',
#  'Southern State Community College',
#  'Southern West Virginia Community and Technical College',
#  'Southside Virginia Community College',
#  'Southwest Tennessee Community College',
#  'Southwest Virginia Community College',
#  'Southwest Wisconsin Technical College',
#  'Southwestern Illinois College',
#  'Spartanburg Community College',
#  'Spokane Community College',
#  'Spokane Falls Community College',
#  'Spoon River College',
#  'Springfield Technical Community College',
#  'St. Charles Community College',
#  'St. Clair County Community College',
#  'St. Petersburg College',
#  "St. Philip's College",
#  "St. Vincent's College",
#  'Stanly Community College',
#  'Stark State College',
#  'State College of Florida, Manatee-Sarasota',
#  'Stevens Institute of Business & Arts',
#  'Stone Child College',
#  'Surry Community College',
#  'Tacoma Community College',
#  'Tallahassee Community College',
#  'Technical Career Institutes',
#  'Technical College of the Lowcountry',
#  'Temple College',
#  'Terra State Community College',
#  'Texarkana College',
#  'Texas Tech University Health Sciences Center',
#  'Thomas Edison State University',
#  'Thomas Nelson Community College',
#  'Tidewater Community College',
#  'Touro University Worldwide',
#  'Tri-County Community College',
#  'Tri-County Technical College',
#  'Tri-State Bible College',
#  'Trident Technical College',
#  'Trident University International',
#  'Trinity College of Nursing & Health Sciences',
#  'Triton College',
#  'Trocaire College',
#  'Truckee Meadows Community College',
#  'Tulsa Community College',
#  'Tunxis Community College',
#  'University of Arkansas for Medical Sciences',
#  'University of Baltimore',
#  'University of Houston-Clear Lake',
#  'University of Houston-Downtown',
#  'University of Maine at Augusta',
#  'University of Nebraska Medical Center',
#  'University of New Hampshire at Manchester',
#  'University of Pittsburgh at Greensburg',
#  'University of Texas Health Science Center at Houston',
#  'Valencia College',
#  'Vance-Granville Community College',
#  'Ventura College',
#  'Victoria College',
#  'Villa Maria College of Buffalo',
#  'Virginia Baptist College',
#  'Virginia Highlands Community College',
#  'Virginia Western Community College',
#  'Volunteer State Community College',
#  'Wake Technical Community College',
#  'Walden University',
#  'Walla Walla Community College',
#  'Walsh College of Accountancy and Business Administration',
#  'Walters State Community College',
#  'Warren County Community College',
#  'Washtenaw Community College',
#  'Waubonsee Community College',
#  'Waukesha County Technical College',
#  'Wayne Community College',
#  'West Kentucky Community and Technical College',
#  'West Los Angeles College',
#  'West Shore Community College',
#  'West Valley College',
#  'West Virginia Northern Community College',
#  'West Virginia University at Parkersburg',
#  'Westchester Community College',
#  'Western Dakota Technical Institute',
#  'Western Governors University',
#  'Western Nevada College',
#  'Western Piedmont Community College',
#  'Westmoreland County Community College',
#  'Whatcom Community College',
#  'White Earth Tribal and Community College',
#  'White Mountains Community College',
#  'Wichita Area Technical College',
#  'Wilkes Community College',
#  'Williamsburg Technical College',
#  'Wilson Community College',
#  'Wiregrass Georgia Technical College',
#  'Woodland Community College',
#  'Wor-Wic Community College',
#  'World Mission University',
#  'Wytheville Community College',
#  "Yeshiva Gedolah Imrei Yosef D'Spinka",
#  'York County Community College',
#  'York Technical College',
#  'Yuba College',
#  'Zane State College']

# %%
df.loc[room_board_null].groupby("name").count().reset_index()
# Out:
#                                      name  total_enrollment  state  category  \
# 0                  Aaniiih Nakoda College                11     11        11
# 1                         Academy College                11     11        11
# 2           Advanced Technology Institute                11     11        11
# 3                 Aiken Technical College                11     11        11
# 4                  Aims Community College                11     11        11
# ..                                    ...               ...    ...       ...
# 754  Yeshiva Gedolah Imrei Yosef D'Spinka                11     11        11
# 755         York County Community College                11     11        11
# 756                York Technical College                11     11        11
# 757                          Yuba College                11     11        11
# 758                    Zane State College                11     11        11
#
#      enrollment  state_code  type  degree_length  room_and_board  \
# 0            11          11    11             11               0
# 1            11          11    11             11               0
# 2            11          11    11             11               0
# 3            11          11    11             11               0
# 4            11          11    11             11               0
# ..          ...         ...   ...            ...             ...
# 754          11          11    11             11               0
# 755          11          11    11             11               0
# 756          11          11    11             11               0
# 757          11          11    11             11               0
# 758          11          11    11             11               0
#
#      in_state_tuition  in_state_total  out_of_state_tuition  \
# 0                  11              11                    11
# 1                  11              11                    11
# 2                  11              11                    11
# 3                  11              11                    11
# 4                  11              11                    11
# ..                ...             ...                   ...
# 754                11              11                    11
# 755                11              11                    11
# 756                11              11                    11
# 757                11              11                    11
# 758                11              11                    11
#
#      out_of_state_total  degree_year_length
# 0                    11                  11
# 1                    11                  11
# 2                    11                  11
# 3                    11                  11
# 4                    11                  11
# ..                  ...                 ...
# 754                  11                  11
# 755                  11                  11
# 756                  11                  11
# 757                  11                  11
# 758                  11                  11
#
# [759 rows x 14 columns]

# %%
df.loc[["room_and_board"] == pd.isnull("room_and_board")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [109], in <cell line: 1>()
# ----> 1 df.loc[["room_and_board"] == pd.isnull("room_and_board")]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1201, in _LocIndexer._getitem_axis(self, key, axis)
#    1198         return self.obj.iloc[tuple(indexer)]
#    1200 # fall thru to straight lookup
# -> 1201 self._validate_key(key, axis)
#    1202 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1011, in _LocIndexer._validate_key(self, key, axis)
#    1001 @doc(_LocationIndexer._validate_key)
#    1002 def _validate_key(self, key, axis: int):
#    1003     # valid for a collection of labels (we check their presence later)
#    1004     # slice of labels (where start-end in labels)
#    1005     # slice of integers (only if in the labels)
#    1006     # boolean not in slice and with boolean index
#    1007     if isinstance(key, bool) and not (
#    1008         is_bool_dtype(self.obj._get_axis(axis))
#    1009         or self.obj._get_axis(axis).dtype.name == "boolean"
#    1010     ):
# -> 1011         raise KeyError(
#    1012             f"{key}: boolean label can not be used without a boolean index"
#    1013         )
#    1015     if isinstance(key, slice) and (
#    1016         isinstance(key.start, bool) or isinstance(key.stop, bool)
#    1017     ):
#    1018         raise TypeError(f"{key}: boolean values can not be used in a slice")
#
# KeyError: 'False: boolean label can not be used without a boolean index'

# %%
df_propper = df.groupby(["name","state"]).count().reset_index()

# %%
df_propper

# %%
px.bar(df_propper, x = "name", y = df.value_count("state"))

# %%
s = df_name["state"].value_counts()

# %%
s

# %%
len(df)

# %%
sum(s)

# %%
df.loc[df["state"] == "California"]

# %%
df.loc[df["name"] == "Aaniiih Nakoda College"]

# %%
df.loc[df["name"] == "Aaniiih Nakoda College"]["enrollment"].sum()

# %%
df.groupby(["name"]).sum()

# %%
fig = px.bar(df.groupby("category").sum() , x = "category", y = "enrollment")
fig

# %%
df.loc[df["name"] == "Aaniiih Nakoda College"]["total_enrollment"]

# %%
df_grouped = df.groupby(["name", "category"]).sum().reset_index()

# %%
df.sort_values("name")["enrollment"]

# %%
#df_grouped["minnority_enrollment"] = df.sort_values("name")["enrollment"]

# %%
df_grouped

# %%
df.loc[df["name"] == "Zane State College"]

# %%
df_grouped[df_grouped["name"] == "Zane State College"]

# %%
df.head()

# %%
fig = px.bar(df_grouped[df_grouped["name"] == "Zane State College"], x = "name", y = "enrollment", color = "category", text_auto = True, barmode = "group")
fig

# %%
fig = px.bar(df_grouped[df_grouped["name"] == "Zane State College"].groupby("name").min().reset_index(), x = "name", y = ["in_state_tuition", "out_of_state_tuition"], text_auto = True, barmode = "group")
fig

# %%
df["name"].unique().tolist()

# %%
# Total Pie Chart
fig = px.pie(df_grouped, values = "enrollment", names = "category", title = "Breakdown of Student Demographics for All Schools")
fig

# %%
fig = px.bar(df_grouped.groupby("category").sum().reset_index() , x = "category", y = "enrollment", color = "category", text_auto = True, title = "College Enrollment by Demographic")
fig

# %%
df_grouped[df_grouped["name"] == "Zane State College"]["enrollment"].sum() - df_grouped[df_grouped["name"] == "Zane State College"]["total_enrollment"].min()

# %%
df_grouped[df_grouped["name"] == "Zane State College"]["total_enrollment"]

# %%
df_grouped["total_enrollment"]

# %%
df_grouped.groupby("name").min().reset_index()

# %%
df_grouped.groupby("name").min().reset_index()["total_enrollment"].sum()

# %%
df_grouped.loc[df_grouped["category"] ==  "Total Minority"]

# %%
df_grouped.loc[df_grouped["category"] ==  "Total Minority"]["enrollment"]

# %%
df_grouped.loc[df_grouped["category"] ==  "Total Minority"]["enrollment"].sum()

# %%
df_grouped["total_enrollment"]

# %%
df_grouped[["total_enrollment"] == np.null]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 df_grouped[["total_enrollment"] == np.null]
#
# NameError: name 'df_grouped' is not defined

# %%
pd.notnull(df["room_and_board"])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 23689    False
# 23690    False
# 23691    False
# 23692    False
# 23693    False
# Name: room_and_board, Length: 23694, dtype: bool

# %% [markdown]
# #df.to_csv("college_degree_cleaned.csv", index = False)

# %%
type(df_name["room_and_board"][0])

# %%
df.columns
# Out:
# Index(['name', 'total_enrollment', 'state', 'category', 'enrollment',
#        'state_code', 'type', 'degree_length', 'room_and_board',
#        'in_state_tuition', 'in_state_total', 'out_of_state_tuition',
#        'out_of_state_total', 'degree_year_length'],
#       dtype='object')
